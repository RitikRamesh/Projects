# %%
import cv2
import pandas as pd
import numpy as np
from sklearn import *
import tensorflow as tf
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.image import load_img,img_to_array

# %%
model=load_model('mymodel.h5')
cascade=cv2.CascadeClassifier('haarcascade_frontalface_default.xml')


cap=cv2.VideoCapture(0)

while(cap.isOpened()):
       _,frame=cap.read()
       faces=cascade.detectMultiScale(frame,minNeighbors=4,scaleFactor=1.1)
       for x,y,w,h in faces:
           face=frame[y:y+h,x:x+w]
           cv2.imwrite("face.jpg",face)
           face=load_img("face.jpg",target_size=(150,150,3))#Convert to  numpy
           face=img_to_array(face)
           face=np.expand_dims(face,axis=0)#Convert into 4d
           pred=model.predict(face)
           if pred>0.5:
               cv2.rectangle(frame,(x,y),(x+w,y+h),(0,0,255),3)
               cv2.putText(frame,"No mask",(x,y),1,2,(0,0,255))
           else:
               cv2.rectangle(frame,(x,y),(x+w,y+h),(0,255,0),3)
               cv2.putText(frame,"Mask",(x,y),1,2,(0,255,0))     
       cv2.imshow("window",frame)
       if cv2.waitKey(1)==ord('q'):
           break
  
cap.release()
cv2.destroyAllWindows()
# Out:
# ...
# 1/1 [==============================] - 0s 14ms/step

# %%
# model=tf.keras.models.load_model('facemaskmodel.h5')
# cascade=cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

# cap=cv2.VideoCapture(0)

# while cap.isOpened():
#     var,frame=cap.read()                #return two things
#     faces=cascade.detectMultiScale(frame,scaleFactor=1.1,minNeighbors=4)
#     for x,y,w,h in faces:
#         face=frame[y:y+h,x:x+w]                                     #extracting face from image
#         cv2.imwrite('face.jpg',face)                                #saving face to hardware
#         face=image.load_img('face.jpg',target_size=(150,150,3))
#         face=image.img_to_array(face)                               #convert to numpy array
#         face=np.expand_dims(face,axis=0)
#         #150 150 3  BatchSize     16 150 150 3
#         ans=model.predict(face)                                     # expand dimensions to 4-D 
#         if ans>0.5:
#             print('No mask')
#             cv2.rectangle(frame,(x,y),(x+w,y+h),3,(0,0,255))  #in open cvr rgb becomes bgr
#             cv2.putText(frame,'No Mask',(x,y),2,3,(0,0,255))
#             #255 0 0
#             #0 0 255
#         else:
#             print('With mask')
#             cv2.rectangle(frame,(x,y),(x+w,y+h),3,(0,255,0))  #in open cvr rgb becomes bgr
#             cv2.putText(frame,'With Mask',(x,y),2,3,(0,255,0))
        
#     cv2.imshow('frame',frame)
#     if cv2.waitKey(1)==113:             #Acci Value of q
#         break
    
# cap.release()
# cv2.destroyAllWindows()
